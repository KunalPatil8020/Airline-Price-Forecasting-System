# %% [markdown]
# ## Setup

# %%
# Attching a google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# change the directort with a google drive directory to avoid a loss of output or data if runtime finish
# %cd /content/drive/MyDrive/1Placement_24-25/Bungee Tech/Assessment - II
# Out:
# /content/drive/MyDrive/1Placement_24-25/Bungee Tech/Assessment - II

# %%
# Unzip a data fie
# !unzip Dataset.csv.zip
# Out:
# Archive:  Dataset.csv.zip
#   inflating: Clean_Dataset.csv

# %%
# Importing all the Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
#
#
# 1.   Data Loading and Initial Inspection:
#
# *   Load the dataset into a DataFrame and inspect the first few rows to get an overview of the dataset structure and check the presence of relevant features.
#
#
# 2.   Dataset Information and Data Types:
#
# *   Know the data types of each column and check for non-null values.
#
# 3.  Check the missing values and Drop Unnecessary Columns:
#
# *  Check for missing values in each column.
# *  Clean up the dataset by eliminating columns that are not needed for analysis.
#
#
# 4.  Statistical Summary of the Data:
#
# *   Understand the distribution of numerical variables
# *   Find relationships between numerical features, especially how they relate to the target variable

# %%
# To see what is in the Data
data=pd.read_csv('Clean_Dataset.csv')
data.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
# Information abou the Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
# Droping the useless column 'Unnamed: 0'
data.drop(columns='Unnamed: 0',inplace=True)
data.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
# Checking for missing values in each column
data.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
# Stastical Description of Data
data.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %%
# Size of the data
data.shape
# Out:
# (300153, 11)

# %%
# correlation matrix to find relationships between numerical variables
data1=data.select_dtypes(include=[np.number])
data1.corr().T
# Out:
#            duration  days_left     price
# duration   1.000000  -0.039157  0.204222
# days_left -0.039157   1.000000 -0.091949
# price      0.204222  -0.091949  1.000000

# %%
# Plotting the distribution of flights per airline
sns.countplot(x='airline',data=data)
plt.xlabel('Airline')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Boxplot to check how price varies across different airlines
sns.boxplot(x='airline', y='price', data=data)
plt.xlabel('Airline')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Subplot Analysis to Compare Price across Different Features

plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
sns.boxplot(x='airline', y='price', data=data)
plt.title('Airline vs Price')
plt.xlabel('Airline')
plt.ylabel('Price')

plt.subplot(3,2,2)
sns.boxplot(x='source_city', y='price', data=data)
plt.title('Source City vs Price')
plt.xlabel('Source City')
plt.ylabel('Price')

plt.subplot(3,2,3)
sns.boxplot(x='departure_time', y='price', data=data)
plt.title('Departure Time vs Price')
plt.xlabel('Departure Time')
plt.ylabel('Price')

plt.subplot(3,2,4)
sns.boxplot(x='stops', y='price', data=data)
plt.title('Stops vs Price')
plt.xlabel('Stops')
plt.ylabel('Price')

plt.subplot(3,2,5)
sns.boxplot(x='arrival_time', y='price', data=data)
plt.title('Arrival Time vs Price')
plt.xlabel('Arrival Time')
plt.ylabel('Price')

plt.subplot(3,2,6)
sns.boxplot(x='destination_city', y='price', data=data)
plt.title('Destination City vs Price')
plt.xlabel('Destination City')
plt.ylabel('Price')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
# Boxplot for price comparison across flight classes
sns.boxplot(x='class', y='price', data=data)
plt.title('class vs Price')
plt.xlabel('class')
plt.ylabel('Price')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Text(0, 0.5, 'Price')

# %%
# Duration vs Price comparison, split by class
plt.figure(figsize=(15,8))
sns.lineplot(x='duration',y='price',hue='class', palette='hls',data=data)
plt.title('Duration vs Price')
plt.xlabel('Duration')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Days Left vs Price comparison, split by class
plt.figure(figsize=(15,8))
sns.lineplot(x='days_left',y='price',hue='class', palette='hls',data=data)
plt.title('Days Left vs Price')
plt.xlabel('Days Left')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Duration vs Price comparison, split by airline
plt.figure(figsize=(15,8))
sns.lineplot(x='duration',y='price',hue='airline', palette='hls',data=data)
plt.title('Duration vs Price')
plt.xlabel('Duration')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Days Left vs Price comparison, split by airline
plt.figure(figsize=(15,8))
sns.lineplot(x='days_left',y='price',hue='airline', palette='hls',data=data)
plt.title('Days Left vs Price')
plt.xlabel('Days Left')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
data.groupby(['airline','flight','source_city','destination_city','class'],as_index=False).count()
# Out:
#       airline   flight source_city destination_city     class  departure_time  \
# 0     AirAsia  I5-1228   Bangalore          Chennai   Economy              48
# 1     AirAsia  I5-1228   Bangalore            Delhi   Economy               8
# 2     AirAsia  I5-1228   Bangalore          Kolkata   Economy              40
# 3     AirAsia  I5-1228     Chennai            Delhi   Economy               8
# 4     AirAsia  I5-1228     Chennai           Mumbai   Economy              40
# ...       ...      ...         ...              ...       ...             ...
# 5047  Vistara   UK-996      Mumbai            Delhi   Economy              49
# 5048  Vistara   UK-996      Mumbai        Hyderabad  Business             192
# 5049  Vistara   UK-996      Mumbai        Hyderabad   Economy             142
# 5050  Vistara   UK-996      Mumbai          Kolkata  Business             178
# 5051  Vistara   UK-996      Mumbai          Kolkata   Economy             152
#
# ...

# %%
# Counting the number of flights for each combination of source and destination city
data.groupby(['airline','flight','source_city','destination_city','class'],as_index=False).count().groupby(['source_city','destination_city'],as_index=False)['flight'].count()
# Out:
#    source_city destination_city  flight
# 0    Bangalore          Chennai     106
# 1    Bangalore            Delhi     227
# 2    Bangalore        Hyderabad     132
# 3    Bangalore          Kolkata     171
# 4    Bangalore           Mumbai     175
# 5      Chennai        Bangalore      69
# 6      Chennai            Delhi     105
# 7      Chennai        Hyderabad      82
# 8      Chennai          Kolkata     110
# 9      Chennai           Mumbai      94
# 10       Delhi        Bangalore     310
# 11       Delhi          Chennai     258
# 12       Delhi        Hyderabad     224
# 13       Delhi          Kolkata     306
# 14       Delhi           Mumbai     364
# 15   Hyderabad        Bangalore     103
# 16   Hyderabad          Chennai      91
# 17   Hyderabad            Delhi     121
# 18   Hyderabad          Kolkata     145
# 19   Hyderabad           Mumbai     103
# 20     Kolkata        Bangalore     127
# 21     Kolkata          Chennai      98
# ...

# %%
data.groupby(['airline','source_city','destination_city'],as_index=False)['price'].mean()
# Out:
#      airline source_city destination_city         price
# 0    AirAsia   Bangalore          Chennai   2073.043478
# 1    AirAsia   Bangalore            Delhi   4807.092426
# 2    AirAsia   Bangalore        Hyderabad   2931.494792
# 3    AirAsia   Bangalore          Kolkata   4443.468160
# 4    AirAsia   Bangalore           Mumbai   3342.385350
# ..       ...         ...              ...           ...
# 172  Vistara      Mumbai        Bangalore  35029.880315
# 173  Vistara      Mumbai          Chennai  32181.946251
# 174  Vistara      Mumbai            Delhi  26402.695114
# 175  Vistara      Mumbai        Hyderabad  29497.578017
# 176  Vistara      Mumbai          Kolkata  35223.862417
#
# [177 rows x 4 columns]

# %%
# Make a copy of changed data
data_copy=data.copy()

# %% [markdown]
# ## Data Preprocessing
#
# 1.   Label Encoding: Convert categorical variables into numerical values
# 2.   Feature and Target Split: Define the feature set X and target y
# 3. Feature Importance Calculation: Use Mutual Information to measure the relevance of each feature with respect to the target variable.
# 4. Train-Test Split: Split the dataset into training and testing sets to validate the model’s performance.

# %%
# Label Encoding of Categorical Variables:
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in data.columns:
  if data[col].dtype=='object':
    data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#    airline  flight  source_city  departure_time  stops  arrival_time  \
# 0        4    1408            2               2      2             5
# 1        4    1387            2               1      2             4
# 2        0    1213            2               1      2             1
# 3        5    1559            2               4      2             0
# 4        5    1549            2               4      2             4
#
#    destination_city  class  duration  days_left  price
# 0                 5      1      2.17          1   5953
# 1                 5      1      2.33          1   5953
# 2                 5      1      2.17          1   5956
# 3                 5      1      2.25          1   5955
# 4                 5      1      2.33          1   5955

# %%
# Defining Features and Target Variable:
X=data.drop(columns='price')
y=data['price']

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info_classif(X,y)
# Out:
# array([1.46220249, 4.16866059, 1.89211047, 0.53520954, 0.45313599,
#        0.62506135, 1.72788132, 1.00020625, 2.61413997, 0.63149254])

# %%
# Feature Importance using Mutual Information:
imp=pd.DataFrame(mutual_info_classif(X,y),index=X.columns)
imp.columns=['Importance']
imp.sort_values(by='Importance',ascending=False)
# Out:
#                   Importance
# flight              4.168850
# duration            2.614417
# source_city         1.887082
# destination_city    1.722938
# airline             1.463567
# class               1.004868
# days_left           0.629546
# arrival_time        0.627073
# departure_time      0.530200
# stops               0.455367

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=123)

# %% [markdown]
# ## Model
#
# 1.   Define Evaluation Matrix
# 2.   Model Training

# %%
# Function for Model Evaluation
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
def predict(ml_model):
    print('Model is: {}'.format(ml_model))
    model= ml_model.fit(X_train,y_train)
    print("Training score: {}".format(model.score(X_train,y_train)))
    predictions = model.predict(X_test)
    print("Predictions are: {}".format(predictions))
    print('\n')
    r2score=r2_score(y_test,predictions)
    print("r2 score is: {}".format(r2score))

    print('MAE:{}'.format(mean_absolute_error(y_test,predictions)))
    print('MSE:{}'.format(mean_squared_error(y_test,predictions)))
    print('RMSE:{}'.format(np.sqrt(mean_squared_error(y_test,predictions))))

    sns.distplot(y_test-predictions)

# %%
# XGBoost Regressor
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=6)
predict(xgb_model)
# Out:
# Model is: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
# Training score: 0.9762901067733765
# Predictions are: [38709.688   9308.517   4011.828  ...  4134.0537  5597.303   6735.098 ]
#
#
# r2 score is: 0.9760463833808899
# MAE:1994.0000100137472
# MSE:12293664.758962914
# ...
